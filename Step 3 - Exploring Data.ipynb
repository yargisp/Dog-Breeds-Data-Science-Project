# %% [markdown]
# # Dog Breeds - Data Science project

# %% [markdown]
# # Step 3 : Exploring Data
#
# In this step, we will Visualizing and understanding the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Open CSV file that created on part 2

# %%
breeds = pd.read_csv("dog_breed_data_handling_missing_values.csv",index_col = 0)

# %%
breeds.head()
# Out:
#          breed name   Dog Breed Group                                Height  \
# 0            Afador  Mixed Breed Dogs                       20 to 29 inches
# 1       Affenhuahua  Mixed Breed Dogs                        6 to 12 inches
# 2     Affenpinscher    Companion Dogs   9 to 11 inches tall at the shoulder
# 3      Afghan Hound        Hound Dogs  24 to 26 inches tall at the shoulder
# 4  Airedale Terrier      Terrier Dogs  21 to 23 inches tall at the shoulder
#
#    Height Avg.           Weight  Weight Avg.       Life Span  Life Span Avg.  \
# 0         24.5  50 to 75 pounds         62.5  10 to 12 years            11.0
# 1          9.0   4 to 12 pounds          8.0  13 to 18 years            15.5
# 2         10.0    7 to 9 pounds          8.0  12 to 14 years            13.0
# 3         25.0  50 to 60 pounds         55.0  10 to 12 years            11.0
# 4         22.0  40 to 65 pounds         52.5  10 to 13 years            11.5
#
# ...

# %%
breeds['Life Span Avg.'].hist(bins=10)
plt.xlabel('Life Span Avg.')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
breeds['Life Span Avg.'].hist(bins=10,color='#FF8000',grid=False)
plt.xlabel('Life Span Avg.')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
breeds['Life Span Avg.'].hist(density=True)
# Out:
# <AxesSubplot:>

# %%
breed_list = breeds['Dog Breed Group'].tolist()
breed_set = set(breed_list)
breed_count = []

for val in breed_set:
    breed_count.append(breed_list.count(val))

breed_count
breed_set
# Out:
# {'Companion Dogs',
#  'Herding Dogs',
#  'Hound Dogs',
#  'Hybrid Dogs',
#  'Mixed Breed Dogs',
#  'Sporting Dogs',
#  'Terrier Dogs',
#  'Working Dogs'}

# %%
for val in breed_set:
    print(val + ' ')
    print(breed_list.count(val))
# Out:
# Sporting Dogs
# 41
# Herding Dogs
# 39
# Mixed Breed Dogs
# 123
# Hybrid Dogs
# 15
# Terrier Dogs
# 31
# Companion Dogs
# 45
# Hound Dogs
# 41
# Working Dogs
# 54

# %%
breeds[breeds['Dog Breed Group'] == 'Mixed Breed Dogs']
# Out:
#          breed name   Dog Breed Group           Height  Height Avg.  \
# 0            Afador  Mixed Breed Dogs  20 to 29 inches         24.5
# 1       Affenhuahua  Mixed Breed Dogs   6 to 12 inches          9.0
# 7        Akita Chow  Mixed Breed Dogs  23 to 25 inches         24.0
# 8         Akita Pit  Mixed Breed Dogs  16 to 23 inches         19.5
# 9    Akita Shepherd  Mixed Breed Dogs  24 to 28 inches         26.0
# ..              ...               ...              ...          ...
# 366        Terripoo  Mixed Breed Dogs   9 to 15 inches         12.0
# 367    Texas Heeler  Mixed Breed Dogs  16 to 22 inches         19.0
# 376  Valley Bulldog  Mixed Breed Dogs  12 to 25 inches         18.5
# 382       Westiepoo  Mixed Breed Dogs  11 to 17 inches         14.0
# 384         Whoodle  Mixed Breed Dogs  12 to 20 inches         16.0
#
#                 Weight  Weight Avg.        Life Span  Life Span Avg.  \
# 0      50 to 75 pounds         62.5   10 to 12 years            11.0
# ...

# %%
fig, axes = plt.subplots(figsize=(20,8))
pieData = pd.Series(breed_count, index= breed_set)
pieData.plot(kind='pie', ax=axes,autopct='%.2f%%')
axes.set_title("Dog Breed Group in dataset")
axes.set_ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
breeds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 389 entries, 0 to 388
# Data columns (total 39 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   breed name                       389 non-null    object
#  1   Dog Breed Group                  389 non-null    object
#  2   Height                           388 non-null    object
#  3   Height Avg.                      389 non-null    float64
#  4   Weight                           387 non-null    object
#  5   Weight Avg.                      389 non-null    float64
#  6   Life Span                        389 non-null    object
#  7   Life Span Avg.                   389 non-null    float64
#  8   Adaptability                     389 non-null    int64
#  9   Adapts Well To Apartment Living  389 non-null    int64
#  10  Good For Novice Owners           389 non-null    int64
#  11  Sensitivity Level                389 non-null    int64
# ...

# %%
ct1 = pd.crosstab(breeds['Dog Breed Group'],breeds['Intelligence'])
ct1
# Out:
# Intelligence      1  2   3   4   5
# Dog Breed Group
# Companion Dogs    0  2   8  32   3
# Herding Dogs      0  0   2  19  18
# Hound Dogs        0  0   6  32   3
# Hybrid Dogs       0  0   3   7   5
# Mixed Breed Dogs  0  4  18  66  35
# Sporting Dogs     0  0   3  16  22
# Terrier Dogs      0  0   3  20   8
# Working Dogs      1  2  10  27  14

# %%
ctab_Intelligence = pd.crosstab(breeds['Dog Breed Group'],breeds['Intelligence'],normalize=True)
ctab_Intelligence
# Out:
# Intelligence             1         2         3         4         5
# Dog Breed Group
# Companion Dogs    0.000000  0.005141  0.020566  0.082262  0.007712
# Herding Dogs      0.000000  0.000000  0.005141  0.048843  0.046272
# Hound Dogs        0.000000  0.000000  0.015424  0.082262  0.007712
# Hybrid Dogs       0.000000  0.000000  0.007712  0.017995  0.012853
# Mixed Breed Dogs  0.000000  0.010283  0.046272  0.169666  0.089974
# Sporting Dogs     0.000000  0.000000  0.007712  0.041131  0.056555
# Terrier Dogs      0.000000  0.000000  0.007712  0.051414  0.020566
# Working Dogs      0.002571  0.005141  0.025707  0.069409  0.035990

# %%
ctab_Intelligence.plot(kind='bar',figsize=(15,5))
plt.title('The level of intelligence in each group',fontsize=30)
plt.xlabel('Dog Breed Group')
plt.ylabel('Intelligence')
# Out:
# Text(0, 0.5, 'Intelligence')

# %%
ctab_Dog_Friendly = pd.crosstab(breeds['Dog Breed Group'],breeds['Dog Friendly'],normalize=True)
ctab_Dog_Friendly
ctab_Dog_Friendly.plot(kind='line',figsize=(15,5))
plt.title('The level of Dog Friendly in each group',fontsize=30)
plt.xlabel('Dog Breed Group')
plt.ylabel('Dog Friendly')
# Out:
# Text(0, 0.5, 'Dog Friendly')

# %%
fig = plt.figure(figsize=(10,7))
ax = plt.axes()

color_dict = dict({'Mixed Breed Dogs':'brown',
                  'Hound Dogs':'green',
                  'Working Dogs': 'orange',
                  'Hybrid Dogs': 'red',
                   'Companion Dogs': 'dodgerblue',
                  'Herding Dogs':'grey',
                  'Terrier Dogs':'navy',
                  'Sporting Dogs':'salmon'})

sns.scatterplot(x= 'Weight', y = 'Height',s=70,hue=breeds['Dog Breed Group'],palette=color_dict,data={ 'Height': breeds['Height Avg.'] , 'Weight': breeds['Weight Avg.']})
plt.title('Height & Weight by Dog breed group',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Height & Weight by Dog breed group')

# %% [markdown]
# #### The dominant feature

# %%
clean_df = breeds.copy()
clean_df.drop(['breed name','Height','Affectionate With Family','Height Avg.','Weight','Weight Avg.','Life Span','Life Span Avg.'],inplace=True,axis=1)

listb = list(breed_set)

maximum = 0
feature = ''
for i in range(8):
    for col in clean_df:
        if(col!= 'Dog Breed Group'):
            if (clean_df[clean_df['Dog Breed Group'] == listb[i]].mean()[col] > maximum):
                maximum = clean_df[clean_df['Dog Breed Group'] == listb[i]].mean()[col]
                feature = col
    print("Group name #{name}".format(name = listb[i]))
    print(feature)
    print(maximum)
# Out:
# Group name #Sporting Dogs
# Energy Level
# 4.560975609756097
# Group name #Herding Dogs
# Energy Level
# 4.560975609756097
# Group name #Mixed Breed Dogs
# Energy Level
# 4.560975609756097
# Group name #Hybrid Dogs
# Energy Level
# 4.560975609756097
# Group name #Terrier Dogs
# Potential For Playfulness
# 4.580645161290323
# Group name #Companion Dogs
# Potential For Playfulness
# 4.580645161290323
# Group name #Hound Dogs
# Potential For Playfulness
# 4.580645161290323
# Group name #Working Dogs
# Potential For Playfulness
# 4.580645161290323
